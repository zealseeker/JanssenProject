# %%
import os
import pandas as pd
import numpy as np
import sys
sys.path.append('../Chemistry')
from standardise import *

# %%
folder = r'C:\Users\hy929891\OneDrive - University of Cambridge\Projects\Imaging\data'

# %%
jdf = pd.read_csv(os.path.join(folder, 'idr0088-screenA-annotation.csv'))
jcids = jdf['Compound PubChem CID'].unique()

# %% [markdown]
# ## Overlap with Tox21

# %% [markdown]
# Tox21 data can be downloaded here:
# https://tripod.nih.gov/tox21/assays/

# %%
tox21 = pd.read_csv(os.path.join(folder, 'tox21_10k_library_info.tsv'), sep='\t')
tcids = tox21['PUBCHEM_CID'].unique()

# %%
print('Number of Janssen compounds with cids: {}'.format(len(jcids)))
print('Number of tox21 compounds with cids: {}'.format(len(tcids)))
print('Number of overlap compounds by cid: {}'.format(len(np.intersect1d(jcids, tcids))))
# Out:
# Number of Janssen compounds with cids: 1176
# Number of tox21 compounds with cids: 8748
# Number of overlap compounds by cid: 334

# %% [markdown]
# ### Use Mitochondrial Toxicity (MT) as a example

# %% [markdown]
# The tox21 data from tripod is problematic. For example: in tox21-mitotox-p1.aggregrated.txt, each line is ended with "`\t\t\n`", which means there are two blank filed, however there should be only one blank field, which is PURITY. So we cannot directly use pandas to read the file. I am going to do a tricky thing

# %%
mt = pd.read_csv(os.path.join(folder, 'tox21-mitotox-p1.aggregrated.txt'), sep='\t')
columns = mt.columns.copy()
del mt['PURITY']
mt.columns = columns[1:]
mt.index.name = 'SAMPLE_ID'
mt = mt[pd.notna(mt['PUBCHEM_CID'])]

# %%
print("Number of compounds in this enpdoint: {}".format(len(mt[mt['SAMPLE_DATA_TYPE']=='activity'])))
# Out:
# Number of compounds in this enpdoint: 10496

# %% [markdown]
# ### Overview of the categories in MT

# %%
mt[mt['SAMPLE_DATA_TYPE']=='activity'].groupby('ASSAY_OUTCOME').count()
# Out:
#                                      PROTOCOL_NAME  SAMPLE_DATA_TYPE  \
# ASSAY_OUTCOME
# active agonist                                 296               296
# active antagonist                             1232              1232
# inactive                                      6728              6728
# inconclusive                                   994               994
# inconclusive agonist                           369               369
# inconclusive agonist (cytotoxic)                 6                 6
# inconclusive antagonist                        349               349
# inconclusive antagonist (cytotoxic)            373               373
#
#                                      CHANNEL_OUTCOME  AC50  EFFICACY  \
# ASSAY_OUTCOME
# active agonist                                   296   296       296
# active antagonist                               1232  1232      1232
# inactive                                        6728     0      6728
# inconclusive                                     994   537       994
# inconclusive agonist                             369   195       369
# inconclusive agonist (cytotoxic)                   6     5         6
# inconclusive antagonist                          349   260       349
# inconclusive antagonist (cytotoxic)              373   367       373
#
#                                      REPRODUCIBILITY  CURVE_RANK  FLAG   CAS  \
# ASSAY_OUTCOME
# active agonist                                   296         296    45   296
# active antagonist                               1232        1232   244  1232
# inactive                                        6728        6728   619  6728
# inconclusive                                     994         994   132   994
# inconclusive agonist                             369         369    40   369
# inconclusive agonist (cytotoxic)                   6           6     1     6
# inconclusive antagonist                          349         349    66   349
# inconclusive antagonist (cytotoxic)              373         373    52   373
#
#                                      PUBCHEM_CID  PUBCHEM_SID  PURITY_RATING  \
# ASSAY_OUTCOME
# active agonist                               296          296            281
# active antagonist                           1232         1232           1219
# inactive                                    6728         6728           6546
# inconclusive                                 994          994            967
# inconclusive agonist                         369          369            354
# inconclusive agonist (cytotoxic)               6            6              6
# inconclusive antagonist                      349          349            345
# inconclusive antagonist (cytotoxic)          373          373            357
#
#                                      PURITY_RATING_4M  SAMPLE_NAME  SMILES  \
# ASSAY_OUTCOME
# active agonist                                    252          296     296
# active antagonist                                1085         1232    1232
# inactive                                         5178         6728    6728
# inconclusive                                      797          994     994
# inconclusive agonist                              291          369     369
# inconclusive agonist (cytotoxic)                    3            6       6
# inconclusive antagonist                           297          349     349
# inconclusive antagonist (cytotoxic)               319          373     373
#
#                                      TOX21_ID  PURITY
# ASSAY_OUTCOME
# active agonist                            296       0
# active antagonist                        1232       0
# inactive                                 6728       0
# inconclusive                              994       0
# inconclusive agonist                      369       0
# inconclusive agonist (cytotoxic)            6       0
# inconclusive antagonist                   349       0
# inconclusive antagonist (cytotoxic)       373       0

# %% [markdown]
# ### Overview of overlap with Janssen in terms of PUBCHEM_CID

# %%
mt[(mt['SAMPLE_DATA_TYPE']=='activity')&(mt['PUBCHEM_CID'].isin(jcids))].groupby('ASSAY_OUTCOME').count()
# Out:
#                                      PROTOCOL_NAME  SAMPLE_DATA_TYPE  \
# ASSAY_OUTCOME
# active agonist                                  29                29
# active antagonist                               54                54
# inactive                                       292               292
# inconclusive                                    54                54
# inconclusive agonist                            21                21
# inconclusive antagonist                         23                23
# inconclusive antagonist (cytotoxic)             22                22
#
#                                      CHANNEL_OUTCOME  AC50  EFFICACY  \
# ASSAY_OUTCOME
# active agonist                                    29    29        29
# active antagonist                                 54    54        54
# inactive                                         292     0       292
# inconclusive                                      54    27        54
# inconclusive agonist                              21    15        21
# inconclusive antagonist                           23    18        23
# inconclusive antagonist (cytotoxic)               22    22        22
#
#                                      REPRODUCIBILITY  CURVE_RANK  FLAG  CAS  \
# ASSAY_OUTCOME
# active agonist                                    29          29     3   29
# active antagonist                                 54          54    15   54
# inactive                                         292         292    26  292
# inconclusive                                      54          54     7   54
# inconclusive agonist                              21          21     1   21
# inconclusive antagonist                           23          23     5   23
# inconclusive antagonist (cytotoxic)               22          22     2   22
#
#                                      PUBCHEM_CID  PUBCHEM_SID  PURITY_RATING  \
# ASSAY_OUTCOME
# active agonist                                29           29             27
# active antagonist                             54           54             54
# inactive                                     292          292            290
# inconclusive                                  54           54             54
# inconclusive agonist                          21           21             20
# inconclusive antagonist                       23           23             23
# inconclusive antagonist (cytotoxic)           22           22             22
#
#                                      PURITY_RATING_4M  SAMPLE_NAME  SMILES  \
# ASSAY_OUTCOME
# active agonist                                     26           29      29
# active antagonist                                  53           54      54
# inactive                                          262          292     292
# inconclusive                                       52           54      54
# inconclusive agonist                               19           21      21
# inconclusive antagonist                            21           23      23
# inconclusive antagonist (cytotoxic)                21           22      22
#
#                                      TOX21_ID  PURITY
# ASSAY_OUTCOME
# active agonist                             29       0
# active antagonist                          54       0
# inactive                                  292       0
# inconclusive                               54       0
# inconclusive agonist                       21       0
# inconclusive antagonist                    23       0
# inconclusive antagonist (cytotoxic)        22       0

# %% [markdown]
# ### Overview of overlap with Janssen in terms of InchiKey

# %%
tox21 = pd.read_csv('tox21_inchikey.csv', index_col=0)

# %%
smis = jdf['Compound SMILES'].unique()
mols = pd.Series(smis, index=smis).apply(read_standardise)
inchi_keys = mols.apply(Chem.MolToInchiKey)
# Out:
# ../Chemistry\standardise.py:13: UserWarning: SMILES: nan is invalid
#   warnings.warn('SMILES: {} is invalid'.format(smi))

# %%
mt['std_inchi_key'] = mt['PUBCHEM_CID'].map(tox21['std_inchi_key'])

# %%
mt[(mt['SAMPLE_DATA_TYPE']=='activity')&(mt['std_inchi_key'].isin(inchi_keys.values))].groupby('ASSAY_OUTCOME').count()
# Out:
#                                      PROTOCOL_NAME  SAMPLE_DATA_TYPE  \
# ASSAY_OUTCOME
# active agonist                                  51                51
# active antagonist                               72                72
# inactive                                       413               413
# inconclusive                                    77                77
# inconclusive agonist                            38                38
# inconclusive antagonist                         27                27
# inconclusive antagonist (cytotoxic)             25                25
#
#                                      CHANNEL_OUTCOME  AC50  EFFICACY  \
# ASSAY_OUTCOME
# active agonist                                    51    51        51
# active antagonist                                 72    72        72
# inactive                                         413     0       413
# inconclusive                                      77    38        77
# inconclusive agonist                              38    28        38
# inconclusive antagonist                           27    20        27
# inconclusive antagonist (cytotoxic)               25    25        25
#
#                                      REPRODUCIBILITY  CURVE_RANK  FLAG  CAS  \
# ASSAY_OUTCOME
# active agonist                                    51          51     5   51
# active antagonist                                 72          72    22   72
# inactive                                         413         413    40  413
# inconclusive                                      77          77    13   77
# inconclusive agonist                              38          38     2   38
# inconclusive antagonist                           27          27     7   27
# inconclusive antagonist (cytotoxic)               25          25     2   25
#
#                                      PUBCHEM_CID  PUBCHEM_SID  PURITY_RATING  \
# ASSAY_OUTCOME
# active agonist                                51           51             49
# active antagonist                             72           72             72
# inactive                                     413          413            411
# inconclusive                                  77           77             77
# inconclusive agonist                          38           38             37
# inconclusive antagonist                       27           27             27
# inconclusive antagonist (cytotoxic)           25           25             25
#
#                                      PURITY_RATING_4M  SAMPLE_NAME  SMILES  \
# ASSAY_OUTCOME
# active agonist                                     45           51      51
# active antagonist                                  70           72      72
# inactive                                          363          413     413
# inconclusive                                       75           77      77
# inconclusive agonist                               35           38      38
# inconclusive antagonist                            25           27      27
# inconclusive antagonist (cytotoxic)                24           25      25
#
#                                      TOX21_ID  PURITY  std_inchi_key
# ASSAY_OUTCOME
# active agonist                             51       0             51
# active antagonist                          72       0             72
# inactive                                  413       0            413
# inconclusive                               77       0             77
# inconclusive agonist                       38       0             38
# inconclusive antagonist                    27       0             27
# inconclusive antagonist (cytotoxic)        25       0             25
