# %%
import os
import pandas as pd
import numpy as np

# %%
folder = r'C:\Users\hy929891\OneDrive - University of Cambridge\Projects\Imaging\data'

# %%
jdf = pd.read_csv(os.path.join(folder, 'idr0088-screenA-annotation.csv'))
jcids = jdf['Compound PubChem CID'].unique()

# %% [markdown]
# ## Overlap with Tox21

# %% [markdown]
# Tox21 data can be downloaded here:
# https://tripod.nih.gov/tox21/assays/

# %%
tox21 = pd.read_csv(os.path.join(folder, 'tox21_10k_library_info.tsv'), sep='\t')
tcids = tox21['PUBCHEM_CID'].unique()

# %%
print('Number of Janssen compounds with cids: {}'.format(len(jcids)))
print('Number of tox21 compounds with cids: {}'.format(len(tcids)))
print('Number of overlap compounds by cid: {}'.format(len(np.intersect1d(jcids, tcids))))
# Out:
# Number of Janssen compounds with cids: 1176
# Number of tox21 compounds with cids: 8748
# Number of overlap compounds by cid: 334

# %% [markdown]
# ### Use Mitochondrial Toxicity (MT) as a example

# %% [markdown]
# The tox21 data from tripod is problematic. For example: in tox21-mitotox-p1.aggregrated.txt, each line is ended with "`\t\t\n`", which means there are two blank filed, however there should be only one blank field, which is PURITY. So we cannot directly use pandas to read the file. I am going to do a tricky thing

# %%
mt = pd.read_csv(os.path.join(folder, 'tox21-mitotox-p1.aggregrated.txt'), sep='\t')
columns = mt.columns.copy()
del mt['PURITY']
mt.columns = columns[1:]
mt.index.name = 'SAMPLE_ID'

# %%
print("Number of compounds in this enpdoint: {}".format(len(mt[mt['SAMPLE_DATA_TYPE']=='activity'])))
# Out:
# Number of compounds in this enpdoint: 10496

# %% [markdown]
# ### Overview of the categories in MT

# %%
mt[mt['SAMPLE_DATA_TYPE']=='activity'].groupby('ASSAY_OUTCOME').count()
# Out:
#                                      PROTOCOL_NAME  SAMPLE_DATA_TYPE  \
# ASSAY_OUTCOME
# active agonist                                 297               297
# active antagonist                             1263              1263
# inactive                                      6810              6810
# inconclusive                                  1010              1010
# inconclusive agonist                           377               377
# inconclusive agonist (cytotoxic)                 7                 7
# inconclusive antagonist                        356               356
# inconclusive antagonist (cytotoxic)            376               376
#
#                                      CHANNEL_OUTCOME  AC50  EFFICACY  \
# ASSAY_OUTCOME
# active agonist                                   297   297       297
# active antagonist                               1263  1263      1263
# inactive                                        6810     0      6810
# inconclusive                                    1010   543      1010
# inconclusive agonist                             377   201       377
# inconclusive agonist (cytotoxic)                   7     6         7
# inconclusive antagonist                          356   267       356
# inconclusive antagonist (cytotoxic)              376   370       376
#
#                                      REPRODUCIBILITY  CURVE_RANK  FLAG   CAS  \
# ASSAY_OUTCOME
# active agonist                                   297         297    45   297
# active antagonist                               1263        1263   245  1263
# inactive                                        6810        6810   624  6810
# inconclusive                                    1010        1010   133  1010
# inconclusive agonist                             377         377    40   377
# inconclusive agonist (cytotoxic)                   7           7     1     7
# inconclusive antagonist                          356         356    66   356
# inconclusive antagonist (cytotoxic)              376         376    52   376
#
#                                      PUBCHEM_CID  PUBCHEM_SID  PURITY_RATING  \
# ASSAY_OUTCOME
# active agonist                               296          297            282
# active antagonist                           1232         1263           1250
# inactive                                    6728         6810           6625
# inconclusive                                 994         1010            982
# inconclusive agonist                         369          377            362
# inconclusive agonist (cytotoxic)               6            7              7
# inconclusive antagonist                      349          356            352
# inconclusive antagonist (cytotoxic)          373          376            360
#
#                                      PURITY_RATING_4M  SAMPLE_NAME  SMILES  \
# ASSAY_OUTCOME
# active agonist                                    252          297     296
# active antagonist                                1116         1263    1232
# inactive                                         5250         6810    6729
# inconclusive                                      810         1010     994
# inconclusive agonist                              298          377     370
# inconclusive agonist (cytotoxic)                    4            7       7
# inconclusive antagonist                           304          356     349
# inconclusive antagonist (cytotoxic)               322          376     373
#
#                                      TOX21_ID  PURITY
# ASSAY_OUTCOME
# active agonist                            297       0
# active antagonist                        1263       0
# inactive                                 6810       0
# inconclusive                             1010       0
# inconclusive agonist                      377       0
# inconclusive agonist (cytotoxic)            7       0
# inconclusive antagonist                   356       0
# inconclusive antagonist (cytotoxic)       376       0

# %% [markdown]
# ### Overview of overlap with Janssen

# %%
mt[(mt['SAMPLE_DATA_TYPE']=='activity')&(mt['PUBCHEM_CID'].isin(jcids))].groupby('ASSAY_OUTCOME').count()
# Out:
#                                      PROTOCOL_NAME  SAMPLE_DATA_TYPE  \
# ASSAY_OUTCOME
# active agonist                                  30                30
# active antagonist                               85                85
# inactive                                       374               374
# inconclusive                                    70                70
# inconclusive agonist                            29                29
# inconclusive agonist (cytotoxic)                 1                 1
# inconclusive antagonist                         30                30
# inconclusive antagonist (cytotoxic)             25                25
#
#                                      CHANNEL_OUTCOME  AC50  EFFICACY  \
# ASSAY_OUTCOME
# active agonist                                    30    30        30
# active antagonist                                 85    85        85
# inactive                                         374     0       374
# inconclusive                                      70    33        70
# inconclusive agonist                              29    21        29
# inconclusive agonist (cytotoxic)                   1     1         1
# inconclusive antagonist                           30    25        30
# inconclusive antagonist (cytotoxic)               25    25        25
#
#                                      REPRODUCIBILITY  CURVE_RANK  FLAG  CAS  \
# ASSAY_OUTCOME
# active agonist                                    30          30     3   30
# active antagonist                                 85          85    16   85
# inactive                                         374         374    31  374
# inconclusive                                      70          70     8   70
# inconclusive agonist                              29          29     1   29
# inconclusive agonist (cytotoxic)                   1           1     0    1
# inconclusive antagonist                           30          30     5   30
# inconclusive antagonist (cytotoxic)               25          25     2   25
#
#                                      PUBCHEM_CID  PUBCHEM_SID  PURITY_RATING  \
# ASSAY_OUTCOME
# active agonist                                29           30             28
# active antagonist                             54           85             85
# inactive                                     292          374            369
# inconclusive                                  54           70             69
# inconclusive agonist                          21           29             28
# inconclusive agonist (cytotoxic)               0            1              1
# inconclusive antagonist                       23           30             30
# inconclusive antagonist (cytotoxic)           22           25             25
#
#                                      PURITY_RATING_4M  SAMPLE_NAME  SMILES  \
# ASSAY_OUTCOME
# active agonist                                     26           30      29
# active antagonist                                  84           85      54
# inactive                                          334          374     293
# inconclusive                                       65           70      54
# inconclusive agonist                               26           29      22
# inconclusive agonist (cytotoxic)                    1            1       1
# inconclusive antagonist                            28           30      23
# inconclusive antagonist (cytotoxic)                24           25      22
#
#                                      TOX21_ID  PURITY
# ASSAY_OUTCOME
# active agonist                             30       0
# active antagonist                          85       0
# inactive                                  374       0
# inconclusive                               70       0
# inconclusive agonist                       29       0
# inconclusive agonist (cytotoxic)            1       0
# inconclusive antagonist                    30       0
# inconclusive antagonist (cytotoxic)        25       0
